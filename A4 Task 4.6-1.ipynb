# %% [markdown]
# ### 01 Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 02 import Data

# %%
df_opc = pd.read_pickle(r"C:\Users\SigmaEd\Documents\CareerFoundry\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl")
df_prods = pd.read_csv(r"C:\Users\SigmaEd\Documents\CareerFoundry\Instacart Basket Analysis\02 Data\Prepared Data\products_wrangled.csv")

# %% [markdown]
# ### 03 Explore Data

# %%
df_opc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   order_number            int64
#  4   order_day_or_week       int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  _merge                  category
# dtypes: category(1), float64(1), int64(9)
# memory usage: 2.7 GB

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49672 entries, 0 to 49671
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     49672 non-null  int64
#  1   product_id     49672 non-null  int64
#  2   product_name   49672 non-null  object
#  3   aisle_id       49672 non-null  int64
#  4   department_id  49672 non-null  int64
#  5   prices         49672 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# ### 04 Change _merge column name

# %%
df_opc.rename(columns = {'_merge' : 'first_merge'}, inplace = True)

# %% [markdown]
# ### 05 Merge data

# %%
df_full_merge = df_opc.merge(df_prods, on = ['product_id'], indicator = True)

# %% [markdown]
# ### 06 Check new dataframe

# %%
df_full_merge
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  order_day_or_week  \
# 0                    0   2539329        1             1                  2
# 1                    1   2398795        1             2                  3
# 2                    2    473747        1             3                  3
# 3                    3   2254736        1             4                  4
# 4                    4    431534        1             5                  4
# ...                ...       ...      ...           ...                ...
# 32404854       3360493   1320836   202557            17                  2
# 32404855       3360494     31526   202557            18                  5
# 32404856       3376038    758936   203436             1                  2
# 32404857       3376039   2745165   203436             2                  3
# 32404858       3408036   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# ### 07 Export Data

# %%
df_full_merge.to_pickle(r"C:\Users\SigmaEd\Documents\CareerFoundry\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl")
