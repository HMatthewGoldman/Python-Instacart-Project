# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 02 Import data

# %%
ords_prods_merge = pd.read_pickle(r"C:\Users\SigmaEd\Documents\CareerFoundry\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged4-7.pkl")

# %% [markdown]
# ### 03 Check data

# %%
ords_prods_merge
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  order_day_or_week  \
# 0                    0   2539329        1             1                  2
# 1                    1   2398795        1             2                  3
# 2                    2    473747        1             3                  3
# 3                    3   2254736        1             4                  4
# 4                    4    431534        1             5                  4
# ...                ...       ...      ...           ...                ...
# 32404854       3360493   1320836   202557            17                  2
# 32404855       3360494     31526   202557            18                  5
# 32404856       3376038    758936   203436             1                  2
# 32404857       3376039   2745165   203436             2                  3
# 32404858       3408036   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# ### 04 Dataframe Subset

# %%
df = ords_prods_merge[:1000000]

# %%
df
# Out:
#         Unnamed: 0_x  order_id  user_id  order_number  order_day_or_week  \
# 0                  0   2539329        1             1                  2
# 1                  1   2398795        1             2                  3
# 2                  2    473747        1             3                  3
# 3                  3   2254736        1             4                  4
# 4                  4    431534        1             5                  4
# ...              ...       ...      ...           ...                ...
# 999995       2731921   2836489   164627            14                  0
# 999996       2731962   1843600   164632             5                  1
# 999997       2731966    733106   164632             9                  2
# 999998       2731974   1650124   164632            17                  6
# 999999       2731979   3378258   164632            22                  6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# ### 05 Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# ### 06 Aggregating Data with agg()

# %%
# average number of orders per department ID
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# ### 07 Aggregating Data with transform()

# %%
# create a new column 'max_order' containing the maximum frequency of the “order_number” column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# check data
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  order_day_or_week  \
# 0              0   2539329        1             1                  2
# 1              1   2398795        1             2                  3
# 2              2    473747        1             3                  3
# 3              3   2254736        1             4                  4
# 4              4    431534        1             5                  4
# 5              5   3367565        1             6                  2
# 6              6    550135        1             7                  1
# 7              7   3108588        1             8                  1
# 8              8   2295261        1             9                  1
# 9              9   2550362        1            10                  4
# 10           144   2968173       15            15                  1
# 11           146   1870022       15            17                  2
# 12           147   1911383       15            18                  2
# ...

# %% [markdown]
# ### 08 Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order']<=40) & (ords_prods_merge['max_order']>10), 'loyalty_flag']='Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']<=10, 'loyalty_flag']='New Customer'

# %%
# check data frequency
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# check data
ords_prods_merge[['user_id','max_order','loyalty_flag']].head(60)
# Out:
#     user_id  max_order      loyalty_flag
# 0         1         10      New Customer
# 1         1         10      New Customer
# 2         1         10      New Customer
# 3         1         10      New Customer
# 4         1         10      New Customer
# 5         1         10      New Customer
# 6         1         10      New Customer
# 7         1         10      New Customer
# 8         1         10      New Customer
# 9         1         10      New Customer
# 10       15         22  Regular Customer
# 11       15         22  Regular Customer
# 12       15         22  Regular Customer
# 13       15         22  Regular Customer
# 14       15         22  Regular Customer
# 15       19          9      New Customer
# 16       19          9      New Customer
# 17       19          9      New Customer
# 18       21         33  Regular Customer
# 19       31         20  Regular Customer
# 20       31         20  Regular Customer
# 21       43         11  Regular Customer
# ...
